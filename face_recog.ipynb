# %% [markdown]
# <a href="https://colab.research.google.com/github/HarinCoder/OpenCV/blob/master/face_recog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install face_recognition

# !pip install dlib
# !pip install opencv-python

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

def read_img(path):
  img = cv2.imread(path)
  (h, w) = img.shape(2)
  width = 500
  ratio = width / float(w)
  height = int(h * ratio)
  return cv2.resize(img, (width, height))



known_encodings = []
known_names = []
known_dir = 'known'


for file in os.listdir(known_dir):
  img = read_img(known_dir + '/' + file)
  img_enc = face_recognition.face_encodings(img)[0]
  known_encodings.append(img_enc)
  known_names.append(file.split('.')[0])

known_encodings

#error code

# %% [markdown]
# # working code showing image encoding

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

def read_img(path):
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Failed to read image: {path}")
    (h, w) = img.shape[:2]
    width = 500
    ratio = width / float(w)
    height = int(h * ratio)
    return cv2.resize(img, (width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    try:
        img = read_img(os.path.join(known_dir, file))
        img_enc = face_recognition.face_encodings(img)[0]
        known_encodings.append(img_enc)
        known_names.append(file.split('.')[0])
    except Exception as e:
        print(f"Error processing image {file}: {e}")

known_encodings
# Out:
# Error processing image .ipynb_checkpoints: Failed to read image: known/.ipynb_checkpoints
# [array([-0.13478957,  0.12331195,  0.03778772, -0.05204204, -0.00545248,
#         -0.08609866, -0.01259754, -0.1058875 ,  0.15762341, -0.04980003,
#          0.28870136, -0.06941347, -0.19255905, -0.16065356, -0.00974094,
#          0.16749994, -0.17584662, -0.09890875, -0.06091341, -0.03772267,
#          0.10258865, -0.027741  ,  0.09229773,  0.0807717 , -0.06943192,
#         -0.33430621, -0.13288966, -0.10175956,  0.03443184, -0.04048289,
#         -0.05145042,  0.00439928, -0.24354619, -0.12380274, -0.08515014,
#          0.02801226, -0.01615877, -0.0580141 ,  0.17510387, -0.03159507,
#         -0.1667158 , -0.00784482,  0.03436333,  0.27402985,  0.1962529 ,
#          0.03986133,  0.00417262, -0.05634066,  0.05282307, -0.14187002,
#          0.05171688,  0.15245968,  0.08987413,  0.04183553, -0.04181924,
#         -0.02830685,  0.06412449,  0.09690767, -0.17222948,  0.00945245,
# ...

# %% [markdown]
# # Comparing both the image

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

def read_img(path):
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Failed to read image: {path}")
    (h, w) = img.shape[:2]
    width = 500
    ratio = width / float(w)
    height = int(h * ratio)
    return cv2.resize(img, (width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
  img = read_img(known_dir + '/' + file)
  img_enc = face_recognition.face_encodings(img)[0]
  known_encodings.append(img_enc)
  known_names.append(file.split('.')[0])

unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
  print("processing", file)
  img = read_img(unknown_dir + '/' + file)
  img_encoding = face_recognition.face_encodings(img)[0]

result = face_recognition.compare_faces(known_encodings, img_enc)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-a88e9249fe0a> in <cell line: 20>()
#      19
#      20 for file in os.listdir(known_dir):
# ---> 21   img = read_img(known_dir + '/' + file)
#      22   img_enc = face_recognition.face_encodings(img)[0]
#      23   known_encodings.append(img_enc)
#
# <ipython-input-21-a88e9249fe0a> in read_img(path)
#       7     img = cv2.imread(path)
#       8     if img is None:
# ----> 9         raise ValueError(f"Failed to read image: {path}")
#      10     (h, w) = img.shape[:2]
#      11     width = 500
#
# ValueError: Failed to read image: known/.ipynb_checkpoints

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

def read_img(path):
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Failed to read image: {path}")
    (h, w) = img.shape[:2]
    width = 500
    ratio = width / float(w)
    height = int(h * ratio)
    return cv2.resize(img, (width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    img = read_img(os.path.join(known_dir, file))
    img_enc = face_recognition.face_encodings(img)[0]
    known_encodings.append(img_enc)
    known_names.append(file.split('.')[0])

unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
    print("processing", file)
    img = read_img(os.path.join(unknown_dir, file))
    img_encoding = face_recognition.face_encodings(img)[0]

    result = face_recognition.compare_faces(known_encodings, img_encoding)
    print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-1a8f34c3dfb1> in <cell line: 20>()
#      19
#      20 for file in os.listdir(known_dir):
# ---> 21     img = read_img(os.path.join(known_dir, file))
#      22     img_enc = face_recognition.face_encodings(img)[0]
#      23     known_encodings.append(img_enc)
#
# <ipython-input-22-1a8f34c3dfb1> in read_img(path)
#       7     img = cv2.imread(path)
#       8     if img is None:
# ----> 9         raise ValueError(f"Failed to read image: {path}")
#      10     (h, w) = img.shape[:2]
#      11     width = 500
#
# ValueError: Failed to read image: known/.ipynb_checkpoints

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

def read_img(path):
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Failed to read image: {path}")
    (h, w) = img.shape[:2]
    width = 500
    ratio = width / float(w)
    height = int(h * ratio)
    return cv2.resize(img, (width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    # Filter out non-image files (e.g., .ipynb_checkpoints) using os.path.isfile()
    if os.path.isfile(os.path.join(known_dir, file)):
        img = read_img(os.path.join(known_dir, file))
        img_enc = face_recognition.face_encodings(img)[0]
        known_encodings.append(img_enc)
        known_names.append(file.split('.')[0])

unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
    # Filter out non-image files (e.g., .ipynb_checkpoints) using os.path.isfile()
    if os.path.isfile(os.path.join(unknown_dir, file)):
        print("processing", file)
        img = read_img(os.path.join(unknown_dir, file))
        img_encoding = face_recognition.face_encodings(img)[0]

        result = face_recognition.compare_faces(known_encodings, img_encoding)
        print(result)
# Out:
# processing 2.jpg
# [False, False, False]
# processing 1.jpg
# [False, False, False]
# processing 3.jpg
# [False, False, False]

# %% [markdown]
# # image encodings

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

def read_img(path):
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Failed to read image: {path}")
    (h, w) = img.shape[:2]
    width = 500
    ratio = width / float(w)
    height = int(h * ratio)
    return cv2.resize(img, (width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    # Filter out non-image files (e.g., .ipynb_checkpoints) using os.path.isfile()
    if os.path.isfile(os.path.join(known_dir, file)):
        img = read_img(os.path.join(known_dir, file))
        img_enc = face_recognition.face_encodings(img)[0]
        known_encodings.append(img_enc)
        known_names.append(file.split('.')[0])

unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
    # Filter out non-image files (e.g., .ipynb_checkpoints) using os.path.isfile()
    if os.path.isfile(os.path.join(unknown_dir, file)):
        print("processing", file)
        img = read_img(os.path.join(unknown_dir, file))
        img_encoding = face_recognition.face_encodings(img)[0]

        result = face_recognition.face_distance(known_encodings, img_encoding)
        print(result)
# Out:
# processing 2.jpg
# [0.92958147 0.94582021 0.90800624]
# processing 1.jpg
# [0.78784369 0.65154887 0.62961605]
# processing 3.jpg
# [0.91117192 0.90096938 0.87502839]

# %% [markdown]
# # Detecting face

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

def read_img(path):
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Failed to read image: {path}")
    (h, w) = img.shape[:2]
    width = 500
    ratio = width / float(w)
    height = int(h * ratio)
    return cv2.resize(img, (width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    # Filter out non-image files (e.g., .ipynb_checkpoints) using os.path.isfile()
    if os.path.isfile(os.path.join(known_dir, file)):
        img = read_img(os.path.join(known_dir, file))
        img_enc = face_recognition.face_encodings(img)[0]
        known_encodings.append(img_enc)
        known_names.append(file.split('.')[0])

unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
    # Filter out non-image files (e.g., .ipynb_checkpoints) using os.path.isfile()
    if os.path.isfile(os.path.join(unknown_dir, file)):
        print("processing", file)
        img = read_img(os.path.join(unknown_dir, file))
        img_encoding = face_recognition.face_encodings(img)[0]

        result = face_recognition.face_distance(known_encodings, img_encoding)
        print(result)


        for i in range(len(result)):
          if result[i]:
            name = known_names[i]
            (top,right,bottom,left) = face_recognition.face_locations(img)[0]
            cv2.rectangle(img, (left, top), (right, bottom), (0, 0, 255), 2)
            cv2.putText(img, name, (left+2, top+20), cv2.FONT_HERSHEY_PLAIN, 0.8, (255, 255, 255), 1)
            cv2_imshow(img)
# Out:
# processing 2.jpg
# [0.92958147 0.94582021 0.90800624]
# <PIL.Image.Image image mode=RGB size=500x367>
# <PIL.Image.Image image mode=RGB size=500x367>
# <PIL.Image.Image image mode=RGB size=500x367>
# processing 1.jpg
# [0.78784369 0.65154887 0.62961605]
# <PIL.Image.Image image mode=RGB size=500x333>
# <PIL.Image.Image image mode=RGB size=500x333>
# <PIL.Image.Image image mode=RGB size=500x333>
# processing 3.jpg
# [0.91117192 0.90096938 0.87502839]
# <PIL.Image.Image image mode=RGB size=500x333>
# <PIL.Image.Image image mode=RGB size=500x333>
# <PIL.Image.Image image mode=RGB size=500x333>
